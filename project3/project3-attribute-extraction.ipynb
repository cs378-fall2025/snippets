# %% [markdown]
# ## Project 3 work

# %%
# !pip install json_repair
# Out:
# Collecting json_repair
#   Downloading json_repair-0.50.1-py3-none-any.whl.metadata (10 kB)
# Downloading json_repair-0.50.1-py3-none-any.whl (26 kB)
# Installing collected packages: json_repair
# Successfully installed json_repair-0.50.1

# %% [markdown]
# #### Define common constants and import common libraries

# %%
project_id = "cs378-fa2025"
region = "us-central1"
model_name = "gemini-2.5-pro"
bucket_name = "air-travel-open-data"

# %%
import pandas, json, time, os
from pathlib import Path
from google import genai
from google.genai.types import CreateBatchJobConfig, JobState
from google.cloud import bigquery
from google.cloud import storage

storage_client = storage.Client()
genai_client = genai.Client(vertexai=True, project=project_id, location=region)

# %% [markdown]
# #### Create the temporary dataset in BQ:

# %%
# %%bigquery
#
# create schema air_travel_tmp
#   options (location = 'us-central1');
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Airport Maps

# %%
input_folder_prefix = "initial-loads/airport-maps" # where our input images are located
input_folder = "jsonl/airport-maps"
input_data_path = f"{input_folder}/input-data.jsonl" # used for both the local file and GCS file, contains the prediction requests
input_uri = f"gs://{bucket_name}/{input_data_path}" # complete path to file containing the prediction requests
tmp_table = "air_travel_tmp.airport_maps_data" # output dataset and table in BQ
tmp_table_path = f"bq://{project_id}.{tmp_table}"
tmp_parquet_file = "airport_maps_data.parquet"
lakehouse_parquet_file = f"lakehouse/airport-maps/airport_maps_data.parquet"
system_instruction = """
You are a helpful assistant who reads and understands airport terminal maps. Your goal is to ensure that an airport's businesses are properly reported.
You double-check your answers to make sure you are not mislabeling a business and always return your answers in json format.
"""
prompt = """Which businesses appear on the terminal map of this airport? Return their terminal, business name, category, and the nearest landmarks as they are shown on the map.
If the business is a dining establishment, return the menu items that it is known for.
Make sure your answer conforms to the output schema: {"terminal": "string", "business": "string", "category": "string", "location": "string", "dining": "boolean", "menu_items": "string"}
"""

# %% [markdown]
# #### Run the batch job prediction

# %%
def create_gemini_request(file_list):

    parts = [
        {
            "text": prompt
        }
    ]

    for file_data in file_list:
        parts.append({
            "file_data": {"file_uri": file_data, "mime_type": "application/pdf"}
        })

    request_dict = {
        "system_instruction": {
            "parts": [
                {
                    "text": system_instruction
                }
            ]
        },
        "contents": {
            "role": "user",
            "parts": parts
        },
        "generation_config": {
            "temperature": 1,
        },
    }

    return request_dict

# %%
jsonl_lines = []
file_listing = []
# get the file listings for the maps that we're going to process
bucket = storage_client.bucket(bucket_name)

cur_airport = None
prev_airport = None
num_airports = 0

for blob in bucket.list_blobs(prefix=input_folder_prefix):

    # make a separate dictionary request for each airport
    cur_airport = blob.name.split("-")[2].replace("maps/", "")

    if prev_airport == None or cur_airport == prev_airport:
        file_listing.append(f"gs://{bucket_name}/{blob.name}")
        prev_airport = cur_airport
    else:
        num_airports += 1
        request_dict = create_gemini_request(file_listing)

        jsonl_line = json.dumps({
            "key": prev_airport,  # row identifier
            "request": request_dict
        })

        #print(f"adding {prev_airport} to the input file")
        jsonl_lines.append(jsonl_line)
        file_listing.clear()

        # process cur_airport
        file_listing.append(f"gs://{bucket_name}/{blob.name}")
        prev_airport = cur_airport

if len(file_listing) > 0:
    request_dict = create_gemini_request(file_listing)

    jsonl_line = json.dumps({
        "key": cur_airport,  # use your row identifier here
        "request": request_dict
    })

    num_airports += 1
    jsonl_lines.append(jsonl_line)

print("number of lines in jsonl file:", len(jsonl_lines))

# write all the lines to the jsonl file
dir_path = Path(input_folder)
dir_path.mkdir(parents=True, exist_ok=True)

with open(input_data_path, 'w') as f:
    for line in jsonl_lines:
        f.write(line + '\n')

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(input_data_path)
blob.upload_from_filename(input_data_path)

job = genai_client.batches.create(
    model=model_name,
    src=input_uri,
    config=CreateBatchJobConfig(
    dest=tmp_table_path
  )
)

print(f"Created job: {job.name} with {num_airports} airports")
print(f"Job {job.name} is currently in {job.state} state")
# Out:
# number of lines in jsonl file: 88
# Created job: projects/988876466742/locations/us-central1/batchPredictionJobs/4094091142990135296 with 88 airports
# Job projects/988876466742/locations/us-central1/batchPredictionJobs/4094091142990135296 is currently in JobState.JOB_STATE_PENDING state

# %%
job = genai_client.batches.get(name=job.name)

while job.state not in (JobState.JOB_STATE_SUCCEEDED, JobState.JOB_STATE_FAILED,
                        JobState.JOB_STATE_CANCELLED, JobState.JOB_STATE_PAUSED):
    job = genai_client.batches.get(name=job.name)
    print(f"Job state: {job.state}")
    time.sleep(45)

print(f"Job state: {job.state}")
# Out:
# Job state: JobState.JOB_STATE_PENDING
# Job state: JobState.JOB_STATE_QUEUED
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_SUCCEEDED
# Job state: JobState.JOB_STATE_SUCCEEDED

# %% [markdown]
# #### Check the job results

# %%
# %%bigquery
# select key, response
# from air_travel_tmp.airport_maps_data
# where status not like '%error%'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     key                                           response
# 0   pns  {"candidates":[{"avgLogprobs":-0.5950318842983...
# 1   bzn  {"candidates":[{"avgLogprobs":-0.3319354090813...
# 2   cak  {"candidates":[{"avgLogprobs":-0.3857411111538...
# 3   oma  {"candidates":[{"avgLogprobs":-0.5188454791998...
# 4   lch  {"candidates":[{"avgLogprobs":-0.5910918087562...
# ..  ...                                                ...
# 83  las  {"candidates":[{"avgLogprobs":-0.2409803360766...
# 84  oak  {"candidates":[{"avgLogprobs":-0.4583189660951...
# 85  fll  {"candidates":[{"avgLogprobs":-0.0938675694779...
# 86  lax  {"candidates":[{"avgLogprobs":-0.0598059962473...
# 87  sfo  {"candidates":[{"avgLogprobs":-0.1233262168378...
#
# [88 rows x 2 columns]

# %% [markdown]
# #### Create the parquet file

# %%
import pandas, pandas_gbq
import json
from google.cloud import storage

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

sql = f"""select key, response from {tmp_table} where status not like '%error%'
"""

df = pandas_gbq.read_gbq(
    sql,
    project_id=project_id,
    dialect="standard",
)

prediction_results = [] # key = product_id, value = dictionary containing predictions

# extract predictions from response
for index, row in df.iterrows():
    airport = row["key"]
    response_dict = json.loads(row["response"])
    prediction_str = response_dict["candidates"][0]["content"]["parts"][0]["text"].replace("```", "").replace("json", "")
    prediction_list = json.loads(prediction_str)

    for prediction_dict in prediction_list:
        if type(prediction_dict) != dict:
            print(f"discarding: {prediction_dict}")
            continue
        prediction_dict.update({"airport": airport})
        prediction_results.append(prediction_dict)

print(f"number of results: {len(prediction_results)}")

# convert to parquet file
df = pandas.DataFrame(prediction_results)
df.to_parquet(tmp_parquet_file)
print("converted to parquet")

# upload to our lakehouse folder in GCS
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(lakehouse_parquet_file)
blob.upload_from_filename(tmp_parquet_file)
print(f"wrote parquet file to gs://{bucket_name}/{lakehouse_parquet_file}")
# Out:
# Downloading: 100%|██████████|
# number of results: 1487
# converted to parquet
# wrote parquet file to gs://air-travel-open-data/lakehouse/airport-maps/airport_maps_data.parquet

# %% [markdown]
# #### Create and load the Iceberg table

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE air_travel_raw.airport_maps
# (
#     airport STRING,
#     terminal STRING,
#     business STRING,
#     category STRING,
#     location STRING,
#     dining BOOLEAN,
#     menu_items STRING
# )
# WITH CONNECTION `988876466742.us-central1.cloud-storage-connection`
# OPTIONS (
#  file_format = 'PARQUET',
#  table_format = 'ICEBERG',
#  storage_uri = 'gs://air-travel-open-data/lakehouse/airport-maps'
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# load data into air_travel_raw.airport_maps
#  from files (
#  format = 'parquet',
#  uris = ['gs://air-travel-open-data/lakehouse/airport-maps/airport_maps_data.parquet']);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check the output

# %%
# %%bigquery
# select * from air_travel_raw.airport_maps
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      airport           terminal                           business  category  \
# 0        pns   T1 - First Floor                    Vending Machine    Dining
# 1        pns  T2 - Second Floor                         CNBC Store  Shopping
# 2        pns  T2 - Second Floor                          Gift Shop  Shopping
# 3        pns  T2 - Second Floor              Pensacola Beach House    Dining
# 4        pns  T2 - Second Floor                        Chick-fil-A    Dining
# ...      ...                ...                                ...       ...
# 1482     sfo         Terminal 3  American Express Centurion Lounge    Lounge
# 1483     sfo         Terminal 3             United Global Services    Lounge
# 1484     sfo         Terminal 3                          Yoga Room   Amenity
# 1485     sfo         Terminal 3                        Kids' Spots   Amenity
# 1486     sfo         Terminal 3       COVID-19 Testing, XpresCheck   Service
#
#                                              location  dining  \
# 0     Near the Baggage Offices and Ticketing counters    True
# 1                                         Near Gate 2   False
# 2                                         Near Gate 1   False
# 3                                         Near Gate 4    True
# 4             Near the USO and Airport Administration    True
# ...                                               ...     ...
# 1482                        Concourse F, near Gate F2   False
# 1483                                      Concourse E   False
# 1484                                      Concourse E   False
# 1485                            Near Gates E7 and F18   False
# 1486                                 Level 1 Arrivals   False
#
#                         menu_items
# 0     Menu items not listed on map
# 1
# 2
# 3     Menu items not listed on map
# 4     Menu items not listed on map
# ...                            ...
# 1482                           N/A
# 1483                           N/A
# 1484                           N/A
# 1485                           N/A
# 1486                           N/A
#
# [1487 rows x 7 columns]

# %%
# %%bigquery
# select * from air_travel_raw.airport_maps
# where airport = 'aus'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    airport        terminal                     business  category  \
# 0      aus  East Concourse                  Mini Market  Shopping
# 1      aus  East Concourse               The Scoreboard    Dining
# 2      aus  East Concourse             Hut's Hamburgers    Dining
# 3      aus  East Concourse                     Pretzels    Dining
# 4      aus  East Concourse                    Starbucks    Dining
# 5      aus  East Concourse                     Brighton  Shopping
# 6      aus  East Concourse               Barton Springs  Shopping
# 7      aus  East Concourse                    Taste ATX    Dining
# 8      aus  East Concourse                   Second Bar    Dining
# 9      aus  East Concourse                 The Beerdrop    Dining
# 10     aus  East Concourse                     24 Diner    Dining
# 11     aus  East Concourse              Salvation Pizza    Dining
# 12     aus  East Concourse                 Costa Coffee    Dining
# 13     aus  East Concourse              Farmer's Fridge    Dining
# 14     aus  East Concourse           Sprinkles Cupcakes    Dining
# 15     aus  East Concourse                      Toy Joy  Shopping
# 16     aus  East Concourse                  Zocalo Cafe    Dining
# 17     aus  East Concourse             Noble Sandwiches    Dining
# 18     aus  East Concourse                Caffe' Medici    Dining
# 19     aus  East Concourse          Tyler's Pop-up Shop  Shopping
# 20     aus  East Concourse                     Parkside    Dining
# 21     aus  East Concourse            EJE Travel Retail  Shopping
# 22     aus  East Concourse                         Jugo    Dining
# 23     aus  East Concourse         The Austin Chronicle  Shopping
# 24     aus  East Concourse                    Vino Volo    Dining
# 25     aus  East Concourse                         ATAB  Shopping
# 26     aus       Ticketing             High Brew Coffee    Dining
# 27     aus       Ticketing              Farmer's Fridge    Dining
# 28     aus   Main Terminal                    Vino Volo    Dining
# 29     aus   Main Terminal                      Flyrite    Dining
# 30     aus   Main Terminal               East Side Pies    Dining
# 31     aus   Main Terminal  Barton Springs Express Nook  Shopping
# 32     aus   Main Terminal              Jet Set Express  Shopping
# 33     aus   Main Terminal   Earl Campbell's Taco Truck    Dining
# 34     aus   Main Terminal                  JO'S Coffee    Dining
# 35     aus   Main Terminal               Austin Article  Shopping
# 36     aus   Main Terminal             Amy's Ice Creams    Dining
# 37     aus   Main Terminal                  Book People  Shopping
# 38     aus   Main Terminal            The Salt Lick BBQ    Dining
# 39     aus   Main Terminal                The Saxon Pub    Dining
# 40     aus   Main Terminal         The Peached Tortilla    Dining
# 41     aus   Main Terminal                   Mad Greens    Dining
# 42     aus   Main Terminal                 Berry Austin    Dining
# 43     aus  West Concourse            Annies Cafe & Bar    Dining
# 44     aus  West Concourse       Ruta Maya Cafe & Books    Dining
# 45     aus  West Concourse            Austin Mercantile  Shopping
# 46     aus  West Concourse                       Jetset  Shopping
# 47     aus  West Concourse                     Haymaker    Dining
# 48     aus  West Concourse               Caribou Coffee    Dining
# 49     aus  West Concourse            ThunderCloud Subs    Dining
# 50     aus  West Concourse              Bartons Springs  Shopping
# 51     aus   Baggage Claim       High Brew Coffee Kiosk    Dining
# 52     aus   Baggage Claim        24-Hour Flowers Kiosk  Shopping
# 53     aus   Baggage Claim              Vending Machine    Dining
# 54     aus   Baggage Claim              Farmer's Fridge    Dining
# 55     aus   Baggage Claim            SIM Cards Vending  Shopping
#
#                                location  dining  \
# 0                          Near Gate 15   False
# 1                          Near Gate 15    True
# 2                          Near Gate 14    True
# 3                          Near Gate 14    True
# 4                          Near Gate 14    True
# 5               Between Gates 14 and 15   False
# 6               Between Gates 13 and 14   False
# 7                          Near Gate 13    True
# 8   Near Gate 13 and Flight Information    True
# 9                          Near Gate 13    True
# 10                         Near Gate 12    True
# 11                         Near Gate 12    True
# 12              Between Gates 11 and 12    True
# 13              Between Gates 11 and 12    True
# 14              Between Gates 11 and 12    True
# 15              Between Gates 11 and 12   False
# 16                         Near Gate 11    True
# 17                         Near Gate 11    True
# 18                          Near Gate 5    True
# 19                          Near Gate 5   False
# 20                          Near Gate 3    True
# 21                          Near Gate 3   False
# 22                          Near Gate 3    True
# 23                          Near Gate 8   False
# 24                          Near Gate 8    True
# 25                         Near Gate 10   False
# 26                       Ticketing Hall    True
# 27                       Ticketing Hall    True
# 28                         Near Gate 22    True
# 29                         Near Gate 22    True
# 30                         Near Gate 22    True
# 31                         Near Gate 22   False
# 32                         Near Gate 21   False
# 33                         Near Gate 21    True
# 34                         Near Gate 21    True
# 35                         Near Gate 20   False
# 36                         Near Gate 20    True
# 37                         Near Gate 20   False
# 38                         Near Gate 20    True
# 39                         Near Gate 18    True
# 40                         Near Gate 17    True
# 41                         Near Gate 17    True
# 42                         Near Gate 16    True
# 43                         Near Gate 31    True
# 44                         Near Gate 30    True
# 45                         Near Gate 30   False
# 46                         Near Gate 28   False
# 47                         Near Gate 24    True
# 48                         Near Gate 26    True
# 49                         Near Gate 23    True
# 50                         Near Gate 23   False
# 51                        Baggage Claim    True
# 52                        Baggage Claim   False
# 53                        Baggage Claim    True
# 54                        Baggage Claim    True
# 55                        Baggage Claim   False
#
#                                            menu_items
# 0
# 1                           Bar food, beer, cocktails
# 2                       Hamburgers, fries, milkshakes
# 3                                       Soft pretzels
# 4                   Coffee, espresso drinks, pastries
# 5
# 6
# 7            Local Austin food, craft beer, cocktails
# 8                           Bar food, cocktails, wine
# 9                                          Craft beer
# 10            American diner food, breakfast, burgers
# 11                                              Pizza
# 12                            Coffee, espresso drinks
# 13  Fresh salads, bowls, and snacks from a vending...
# 14                                           Cupcakes
# 15
# 16           Interior Mexican food, tacos, enchiladas
# 17                                 Gourmet sandwiches
# 18                           Artisan coffee, espresso
# 19
# 20             American bistro fare, oysters, seafood
# 21
# 22                 Fresh juice, smoothies, acai bowls
# 23
# 24             Wine flights, small plates, sandwiches
# 25
# 26                            Canned cold brew coffee
# 27  Fresh salads, bowls, and snacks from a vending...
# 28             Wine flights, small plates, sandwiches
# 29                          Chicken sandwiches, wraps
# 30                                 Pizza by the slice
# 31
# 32
# 33                                         Tacos, BBQ
# 34                Coffee, iced turbo, breakfast tacos
# 35
# 36                              Ice cream, milkshakes
# 37
# 38                  Texas BBQ, brisket, ribs, sausage
# 39                              Bar, beer, live music
# 40                Asian-Southern fusion, tacos, bowls
# 41                         Salads, wraps, grain bowls
# 42                                      Frozen yogurt
# 43                 Cafe fare, sandwiches, salads, bar
# 44                    Organic coffee, pastries, books
# 45
# 46
# 47                    Sandwiches, poutine, craft beer
# 48                Coffee, espresso drinks, sandwiches
# 49                                     Sub sandwiches
# 50
# 51                            Canned cold brew coffee
# 52
# 53                                  Snacks and drinks
# 54  Fresh salads, bowls, and snacks from a vending...
# 55

# %% [markdown]
# #### Add the `_load_time` and `_data_source` fields to the table

# %%
# %%bigquery
#
# alter table air_travel_raw.airport_maps
#     add column _data_source STRING, add column _load_time TIMESTAMP;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# update air_travel_raw.airport_maps
#     set _data_source = 'airport.guide', _load_time = current_timestamp()
#     where 1 = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check final output

# %%
# %%bigquery
#
# select * from air_travel_raw.airport_maps
# where airport = 'lax'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     airport       terminal                          business  category  \
# 0       lax              1             Einstein Bros. Bagels    Dining
# 1       lax              4                       LA Tapenade    Dining
# 2       lax              7             Wolfgang Puck Express    Dining
# 3       lax              8                  Engine Co No. 28    Dining
# 4       lax              2                  Barney's Beanery    Dining
# ..      ...            ...                               ...       ...
# 165     lax  International                         Hugo Boss  Shopping
# 166     lax              6  The Marketplace by Wolfgang Puck    Dining
# 167     lax  International                   iStore Boutique  Shopping
# 168     lax              1                     Trejo's Tacos    Dining
# 169     lax              3                    Chicken + Beer    Dining
#
#           location  dining                                         menu_items  \
# 0     Near Gate 14    True               Bagels, breakfast sandwiches, coffee
# 1     Central Hall    True                Mediterranean sandwiches and salads
# 2    Near Gate 74B    True                  Gourmet pizza, salads, sandwiches
# 3     Near Gate 85    True               American comfort food, steaks, pasta
# 4    Near Gate 23A    True     American diner food, burgers, chili, breakfast
# ..             ...     ...                                                ...
# 165     Great Hall   False                                                N/A
# 166  Near Gate 65A    True  Multiple food concepts including pizza, salads...
# 167     Great Hall   False                                                N/A
# 168   Near Gate 13    True                             Tacos, burritos, bowls
# 169   Near Gate 33    True   Southern comfort food, fried chicken, craft beer
#
#       _data_source                       _load_time
# 0    airport.guide 2025-09-12 22:27:13.846732+00:00
# 1    airport.guide 2025-09-12 22:27:13.846732+00:00
# 2    airport.guide 2025-09-12 22:27:13.846732+00:00
# 3    airport.guide 2025-09-12 22:27:13.846732+00:00
# 4    airport.guide 2025-09-12 22:27:13.846732+00:00
# ..             ...                              ...
# 165  airport.guide 2025-09-12 22:27:13.846732+00:00
# 166  airport.guide 2025-09-12 22:27:13.846732+00:00
# 167  airport.guide 2025-09-12 22:27:13.846732+00:00
# 168  airport.guide 2025-09-12 22:27:13.846732+00:00
# 169  airport.guide 2025-09-12 22:27:13.846732+00:00
#
# [170 rows x 9 columns]

# %% [markdown]
# ### TSA Traffic

# %%
input_folder_prefix = "initial-loads/tsa-traffic" # where our input pdfs are located
input_folder = "jsonl/tsa-traffic"
input_data_path = f"{input_folder}/input-data.jsonl" # used for both the local file and GCS file, contains the prediction requests
input_uri = f"gs://{bucket_name}/{input_data_path}" # complete path to file containing the prediction requests
tmp_table = "air_travel_tmp.tsa_traffic_data" # output dataset and table in BQ
tmp_table_path = f"bq://{project_id}.{tmp_table}"
tmp_parquet_file = "tsa_traffic_data.parquet"
lakehouse_parquet_file = f"lakehouse/tsa-traffic/tsa_traffic_data.parquet"
system_instruction = """
You are a helpful assistant who reads and understands tsa traffic reports. Your goal is to ensure that an airport's traffic patterns is properly reported.
You double-check your answers to make sure you are not mislabeling a checkpoint or reporting wrong numbers and always return your answers in json format.
"""
prompt = """Convert the file to json format. Return the date, hour, airport code, airport name, city, state, checkpoint name, and total traffic reported for each time period and location.
Please make sure that your answer conforms to the output schema:
  {"event_date": "string", "event_hour": "string, "airport_code": "string", "airport_name": "string", "airport_city": "string", "airport_state": "string", "security_checkpoint": "string", "total_traffic": "integer"}
"""

# %% [markdown]
# #### Run the batch job prediction

# %%
def create_gemini_request(file_path):

    parts = [
        {
            "text": prompt
        }
    ]

    parts.append({
        "file_data": {"file_uri": file_path, "mime_type": "application/pdf"}
    })

    request_dict = {
        "system_instruction": {
            "parts": [
                {
                    "text": system_instruction
                }
            ]
        },
        "contents": {
            "role": "user",
            "parts": parts
        },
        "generation_config": {
            "temperature": 1,
        },
    }

    return request_dict

# %%
jsonl_lines = []

# get the file listings for the maps that we're going to process
bucket = storage_client.bucket(bucket_name)

num_reports = 0

for blob in bucket.list_blobs(prefix=input_folder_prefix):

    num_reports += 1

    # make a separate request per pdf
    file_name = blob.name.replace("air-travel-open-data/initial-loads/tsa-traffic", "")
    file_path = f"gs://{bucket_name}/{blob.name}"

    request_dict = create_gemini_request(file_path)

    jsonl_line = json.dumps({
        "key": file_name,  # row identifier
        "request": request_dict
    })

    jsonl_lines.append(jsonl_line)

print("number of lines in jsonl file:", len(jsonl_lines))

# write all the lines to the jsonl file
dir_path = Path(input_folder)
dir_path.mkdir(parents=True, exist_ok=True)

with open(input_data_path, 'w') as f:
    for line in jsonl_lines:
        f.write(line + '\n')

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(input_data_path)
blob.upload_from_filename(input_data_path)

job = genai_client.batches.create(
    model=model_name,
    src=input_uri,
    config=CreateBatchJobConfig(
    dest=tmp_table_path
  )
)

print(f"Created job: {job.name} with {num_reports} tsa reports")
print(f"Job {job.name} is currently in {job.state} state")
# Out:
# number of lines in jsonl file: 61
# Created job: projects/988876466742/locations/us-central1/batchPredictionJobs/6246618250826743808 with 61 tsa reports
# Job projects/988876466742/locations/us-central1/batchPredictionJobs/6246618250826743808 is currently in JobState.JOB_STATE_PENDING state

# %%
job = genai_client.batches.get(name=job.name)

while job.state not in (JobState.JOB_STATE_SUCCEEDED, JobState.JOB_STATE_FAILED,
                        JobState.JOB_STATE_CANCELLED, JobState.JOB_STATE_PAUSED):
    job = genai_client.batches.get(name=job.name)
    print(f"Job state: {job.state}")
    time.sleep(45)

print(f"Job state: {job.state}")
# Out:
# Job state: JobState.JOB_STATE_SUCCEEDED

# %% [markdown]
# #### Check the job results

# %%
# %%bigquery
# select *
# from air_travel_tmp.tsa_traffic_data
# where status not like '%error%'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                                   key status  \
# 0   initial-loads/tsa-traffic/tsa_throughput_data_...
# 1   initial-loads/tsa-traffic/tsa_throughput_data_...
# 2   initial-loads/tsa-traffic/october-15-2023-to-o...
# 3   initial-loads/tsa-traffic/august-7-2022-to-aug...
# 4   initial-loads/tsa-traffic/august-20-2023-to-au...
# ..                                                ...    ...
# 56  initial-loads/tsa-traffic/july-10-2022-to-july...
# 57  initial-loads/tsa-traffic/june-12-2022-to-june...
# 58  initial-loads/tsa-traffic/october-23-2022-to-o...
# 59  initial-loads/tsa-traffic/july-9-2023-to-july-...
# 60  initial-loads/tsa-traffic/december-11-2022-to-...
#
#                      processed_time  \
# 0  2025-09-13 13:42:16.285000+00:00
# 1  2025-09-13 13:32:05.318000+00:00
# 2  2025-09-13 13:21:43.196000+00:00
# 3  2025-09-13 13:21:43.101000+00:00
# 4  2025-09-13 13:21:46.608000+00:00
# ..                              ...
# 56 2025-09-13 13:32:05.640000+00:00
# 57 2025-09-13 13:42:16.209000+00:00
# 58 2025-09-13 13:42:16.204000+00:00
# 59 2025-09-13 13:51:23.243000+00:00
# 60 2025-09-13 13:32:08.504000+00:00
#
#                                               request  \
# 0   {"contents":{"parts":[{"file_data":null,"text"...
# 1   {"contents":{"parts":[{"file_data":null,"text"...
# 2   {"contents":{"parts":[{"file_data":null,"text"...
# 3   {"contents":{"parts":[{"file_data":null,"text"...
# 4   {"contents":{"parts":[{"file_data":null,"text"...
# ..                                                ...
# 56  {"contents":{"parts":[{"file_data":null,"text"...
# 57  {"contents":{"parts":[{"file_data":null,"text"...
# 58  {"contents":{"parts":[{"file_data":null,"text"...
# 59  {"contents":{"parts":[{"file_data":null,"text"...
# 60  {"contents":{"parts":[{"file_data":null,"text"...
#
#                                              response
# 0   {"candidates":[{"avgLogprobs":-0.0232383894120...
# 1   {"candidates":[{"avgLogprobs":-0.0423213001000...
# 2   {"candidates":[{"avgLogprobs":-0.0537476771644...
# 3   {"candidates":[{"avgLogprobs":-0.0855125221046...
# 4   {"candidates":[{"avgLogprobs":-0.0499218318876...
# ..                                                ...
# 56  {"candidates":[{"avgLogprobs":-0.0349749120919...
# 57  {"candidates":[{"avgLogprobs":-0.0456072423814...
# 58  {"candidates":[{"avgLogprobs":-0.0592483836132...
# 59  {"candidates":[{"avgLogprobs":-0.0529459942869...
# 60  {"candidates":[{"avgLogprobs":-0.0584413000854...
#
# [61 rows x 5 columns]

# %% [markdown]
# #### Create the parquet file

# %%
import pandas, pandas_gbq
import json, re
from json_repair import repair_json

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

sql = f"""select key, response from {tmp_table} where status not like '%error%'
"""

df = pandas_gbq.read_gbq(
    sql,
    project_id=project_id,
    dialect="standard",
)

prediction_results = [] # key = product_id, value = dictionary containing predictions

# extract predictions from response
for index, row in df.iterrows():
    file_name = row["key"]
    #print(f"processing: {file_name}")
    response_dict = json.loads(row["response"])
    prediction_str = response_dict["candidates"][0]["content"]["parts"][0]["text"].replace("```", "").replace("json", "").strip()

    prediction_list = [] # stores the list of properly formatted predictions from this response

    try:
        prediction_list = json.loads(prediction_str)
    except Exception as e:
        # ugly code is needed due to invalid json objects in the response
        prediction_str = repair_json(prediction_str)
        prediction_str = re.sub(r"(?<=\d),(?=\d)", "", prediction_str) # remove the comma from the total traffic count
        prediction_list = json.loads(prediction_str)

    for prediction_dict in prediction_list:
        if type(prediction_dict) != dict:
            continue
        prediction_results.append(prediction_dict)

print(f"number of results: {len(prediction_results)}")

with open("final_prediction_str", 'w') as f:
    for line in prediction_results:
        f.write(str(line))

# convert to parquet file
df = pandas.DataFrame(prediction_results)
columns_expected = ['event_date', 'event_hour', 'airport_code', 'airport_name', 'airport_city', 'airport_state', 'security_checkpoint', 'total_traffic']
columns_found = df.columns.tolist()
print("initial columns in dataframe:", columns_found)

for column_found in columns_found:
    if column_found not in columns_expected:
        df = df.drop(column_found, axis=1)

columns_final = df.columns.tolist()
print("final columns in dataframe:", columns_final)

df['total_traffic'] = df['total_traffic'].astype(str)

df.to_parquet(tmp_parquet_file)
print("converted to parquet")

# upload to our lakehouse folder in GCS
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(lakehouse_parquet_file)
blob.upload_from_filename(tmp_parquet_file)
print(f"wrote parquet file to gs://{bucket_name}/{lakehouse_parquet_file}")
# Out:
# Downloading: 100%|██████████|
# number of results: 23449
# initial columns in dataframe: ['event_date', 'event_hour', 'airport_code', 'airport_name', 'airport_city', 'airport_state', 'security_checkpoint', 'total_traffic', 'airport_code BQN', 'total_traffic- 32\n  },\n  {\n    "event_date', 'airport name', 'total_traffic- 358\n  },\n  {\n    "event_date', 'security_checkpoint- "EAST Checkpoint', 'airport_code MDW', 'eventdate', 'A CONC', 'OAK', 'Metropolitan Oakland International', 'Oakland', 'CA', 'TERM2', 'code', 'security_checkpoint A21', 'airport_code_', 'security_checkpoint_name', 'security_checkpoint.1', 'airport_codeDCA', 'e', 'security checkpoint', 'security_checkpoint A-East', 'airport city', 'airport state', 'PRCON', 'Security Checkpoint', 'Terminal A', 'Checkpoint BC', 'Gates B', 'Main Support', 'South Checkpoint', 'Rafael Hernandez A', 'Main', 'Consolidated Checkpoint', 'C1/ETS', 'C3/ETS-1', 'Main-FAI', 'A Checkpoint', 'B Checkpoint', 'Main Checkpoint', 'Checkpoint 1', 'AEX01', 'AGS-1', 'AMA30', 'Domestic Checkpoint', 'AUS01', 'BIL-M', 'BNA Central', 'BOI-Co-pax', 'A1', 'B1', 'C1', 'BQK-A', 'BTR01', 'BZN-Z', 'CAE-A', 'CHA-A', 'CHO-Checkpoint', 'Checkpoint', 'CID Passenger', 'North', 'CLL-01', 'Checkpoint D', 'Checkpoint E', 'B', 'COS Checkpoint', 'CPR 01', 'CRP01', 'CRW01', 'T3-MCP', 'DAB-A', 'North Checkpoint', 'A Bridge', 'South', 'A21', 'B19', 'D22', 'E18', 'DHN-A', 'DSM Passenger Alpha', 'Main-2', 'Main-4', 'EUGZ', 'Terminal', 'C2/ETS', 'EYW Checkpoint', 'Gate', 'FAT Main', 'T1 Checkpoint', 'T2 Checkpoint', 'T3 Checkpoint', 'FSD-L', 'GEG-A/B', 'GEG-C', 'GJT-Z', 'GNV-A', 'GPT-A', 'Checkpoint A', 'GTF Main', 'GUC-01', 'HDN-A', 'HHH-01', 'HNL1', 'HNL2', 'HNL3', 'Main Terminal', 'HSV-A', 'East Mezzanine', 'FIS Checkpoint', 'B/DCS Terminal', "E/Int'l", 'FIS-B Terminal', 'North Terminal', 'IDA-Dep', 'IPL-1', 'JAN Main', 'Terminal 1', 'Terminal 2', 'Terminal 4 Main', 'Terminal 5', 'Terminal 7', 'Main Pass Area', 'KOA02', 'KTN-01', 'Term 1 - C/D', 'Term 1-A/B', 'Terminal 3 - E Gates', 'LAW01', 'Term 1 - D/E', 'Terminal 1 - Passenger', 'Terminal 2 - Passenger', 'Terminal 3 - Passenger', 'Terminal 4 - Passenger', 'Terminal 5 - Passenger', 'LBBA', 'T2 C-K Pre-ev', 'LIH01', 'LITA', 'LRD 01', 'LWS-Gate', 'MAFA', 'Passenger Terminal', 'Passenger Screening Checkpoint', 'EAST Checkpoint', 'MDT Main Terminal', 'MDW Checkpoint 2', 'MEM-B', 'MFE01', 'MGM-A', 'Central', 'Concourse G', 'North-2', 'North-5', 'South-1', 'CONC D', 'MLB-A', 'MLU01', 'MOB-A', 'Main Security Screen', 'North CP', 'South CP', 'MSY01', 'T2CKPT', 'T2', '1', '10', '4B', '5', '7A', '8', 'PBI-C', 'PDX-ABC', 'PDX-DE', 'Checkpoint B', 'Checkpoint D/E', 'Checkpoint F', 'PNS-A', 'RDM-Z', 'Terminal 2 Checkpoint', 'RIC-North', 'ROA01', 'CP Terminal 2', 'SAT01', 'SAV-A', 'SDF-A', 'SCP 1', 'SCP 3', 'Employee Security Checkpoint B', 'Security Checkpoint F-3', 'Security Checkpoint G', 'Checkpoint SHV', 'Terminal B North', 'SJTA', 'Checkpoint 2', 'T1-C', 'T2-E', 'Center', 'TPA C', 'TPA E', 'Concourse B', 'ACP', 'VPS-C', 'ABE Main Checkpoint', 'ABIA', 'ABY-A', 'Adak', 'ALC Passenger', 'F Arrival Checkpoint', 'Lower North Checkpoint', 'New T North Checkpoint', 'T North Checkpoint', 'AUS02a', 'BROA', 'Burbank A', 'Burbank B', 'D/E Checkpoint', 'Screening Checkpoint', 'Checkpoint C', 'C', 'Main / Pre-screening', 'A35', 'B30', 'C21', 'D18', 'D30', 'E33', 'Main-3', 'event hour', 'airport_code SEA', 'total_traffic_for_the_hour', 'TVC', 'airport_codeMCO', 'total_traffic_reported', 'security_ checkpoint', 'airport州', 'airport_code SFO', 'security_checkpointA Bridge', 'IA', 'MAIN', 'tate', 'isto', 'PR', 'total traffic', 'total_traffic G', 'checkpoint', 'event_date GSU', 'event A_hour', 'airport_code JAX', '_date', 'airport_code BWI', 'BNA', 'GUM', 'LNK', 'eventDate', 'eventHour', 'airport_code TPA', 'AZO', 'Kalamazoo', 'event_date_', 'airport_name Wichita Dwight D. Eisenhower National', 'airport_code EWR', 'airportcode', 'airport_code MCO', 'd', 'airport_codeBTR', 'comment']
# final columns in dataframe: ['event_date', 'event_hour', 'airport_code', 'airport_name', 'airport_city', 'airport_state', 'security_checkpoint', 'total_traffic']
# converted to parquet
# wrote parquet file to gs://air-travel-open-data/lakehouse/tsa-traffic/tsa_traffic_data.parquet

# %% [markdown]
# #### Create and load the Iceberg table

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE air_travel_raw.tsa_traffic
# (
#     event_date STRING,
#     event_hour STRING,
#     airport_code STRING,
#     airport_name STRING,
#     airport_city STRING,
#     airport_state STRING,
#     security_checkpoint STRING,
#     total_traffic STRING
# )
# WITH CONNECTION `988876466742.us-central1.cloud-storage-connection`
# OPTIONS (
#  file_format = 'PARQUET',
#  table_format = 'ICEBERG',
#  storage_uri = 'gs://air-travel-open-data/lakehouse/tsa-traffic'
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# load data into air_travel_raw.tsa_traffic
#  from files (
#  format = 'parquet',
#  uris = ['gs://air-travel-open-data/lakehouse/tsa-traffic/tsa_traffic_data.parquet']);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check the output

# %%
# %%bigquery
# select * from air_travel_raw.tsa_traffic
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        event_date event_hour airport_code                      airport_name  \
# 0      11/19/2017      00:00          BQN                  Rafael Hernandez
# 1      11/19/2017      00:00          FAI           Fairbanks International
# 2      11/19/2017      00:00          FAT               Fresno Air Terminal
# 3      11/19/2017      00:00          GUM  Antonio B. Won Pat International
# 4      11/19/2017      00:00          IAG       Niagara Falls International
# ...           ...        ...          ...                               ...
# 23444  06/28/2022  0220-0320          TPA               Tampa International
# 23445  06/28/2022  0220-0320          TPA               Tampa International
# 23446   7/17/2023  0400-0500          TPA               Tampa International
# 23447   7/17/2023  0400-0500          TPA               Tampa International
# 23448   7/17/2023  0400-0500          TPA               Tampa International
#
#         airport_city airport_state   security_checkpoint total_traffic
# 0          Aguadilla            PR  Rafael Hernandez Air            20
# 1          Fairbanks            AK              ASAA-FAI           108
# 2             Fresno            CA                FAT 01            11
# 3           Tamuning            GU                 GUM01           260
# 4      Niagara Falls            NY                IAG-01            18
# ...              ...           ...                   ...           ...
# 23444          Tampa            FL                 TPA-C           347
# 23445          Tampa            FL                 TPA-F             5
# 23446          Tampa            FL                 TPA-C           328
# 23447          Tampa            FL                 TPA-E           251
# 23448          Tampa            FL                 TPA-F           197
#
# [23449 rows x 8 columns]

# %% [markdown]
# #### Add the `_load_time` and `_data_source` fields to the table

# %%
# %%bigquery
#
# alter table air_travel_raw.tsa_traffic
#     add column _data_source STRING, add column _load_time TIMESTAMP;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# update air_travel_raw.tsa_traffic
#     set _data_source = 'tsa', _load_time = current_timestamp()
#     where 1 = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check final output

# %%
# %%bigquery
#
# select * from air_travel_raw.tsa_traffic
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        event_date     event_hour airport_code  \
# 0      11/19/2017          03:00          GSP
# 1      11/19/2017          04:00          CHS
# 2      11/19/2017          04:00          TRI
# 3      10/23/2023      0300-0400          HPN
# 4      10/23/2023      0300-0400          ICT
# ...           ...            ...          ...
# 23444  11/26/2017          02:00          TPA
# 23445  11/26/2017          03:00          TPA
# 23446  11/13/2023  04:00 - 04:59          TPA
# 23447   2/12/2024      0100-0200          TPA
# 23448   7/17/2023      0400-0500          TPA
#
#                                 airport_name  airport_city airport_state  \
# 0                     Greenville-Spartanburg         Green            SC
# 1            Charleston County International    Charleston            SC
# 2                          Tri City Regional   Blountville            TN
# 3                         Westchester County  White Plains            NY
# 4      Wichita Dwight D. Eisenhower National       Wichita            KS
# ...                                      ...           ...           ...
# 23444                    Tampa International         Tampa            FL
# 23445                    Tampa International         Tampa            FL
# 23446                    Tampa International         Tampa            FL
# 23447                    Tampa International         Tampa            FL
# 23448                    Tampa International         Tampa            FL
#
#       security_checkpoint total_traffic _data_source  \
# 0              Checkpoint           147          tsa
# 1              Checkpoint           156          tsa
# 2                   TRI-A             1          tsa
# 3           Main Terminal             1          tsa
# 4            Wichita Main             4          tsa
# ...                   ...           ...          ...
# 23444               TPA E             0          tsa
# 23445               TPA F            50          tsa
# 23446               TPA-F           147          tsa
# 23447               TPA C            34          tsa
# 23448               TPA-C           328          tsa
#
#                             _load_time
# 0     2025-09-13 17:22:26.134702+00:00
# 1     2025-09-13 17:22:26.134702+00:00
# 2     2025-09-13 17:22:26.134702+00:00
# 3     2025-09-13 17:22:26.134702+00:00
# 4     2025-09-13 17:22:26.134702+00:00
# ...                                ...
# 23444 2025-09-13 17:22:26.134702+00:00
# 23445 2025-09-13 17:22:26.134702+00:00
# 23446 2025-09-13 17:22:26.134702+00:00
# 23447 2025-09-13 17:22:26.134702+00:00
# 23448 2025-09-13 17:22:26.134702+00:00
#
# [23449 rows x 10 columns]
