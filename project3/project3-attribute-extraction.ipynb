# %% [markdown]
# ## Project 3 work

# %% [markdown]
# #### Define common constants and import common libraries

# %%
project_id = "cs378-fa2025"
region = "us-central1"
model_name = "gemini-2.5-pro"
bucket_name = "air-travel-open-data"

# %%
import pandas, json, time, os
from google import genai
from google.genai.types import CreateBatchJobConfig, JobState
from google.cloud import bigquery
from google.cloud import storage

# %% [markdown]
# ### Airport Maps

# %%
input_folder_prefix = "initial-loads/airport-maps" # where our input images are located
input_folder = "jsonl/airport-maps"
input_data_path = f"{input_folder}/input-data.jsonl" # used for both the local file and GCS file, contains the prediction requests
input_uri = f"gs://{bucket_name}/{input_data_path}" # complete path to file containing the prediction requests
tmp_table = "air_travel_tmp.airport_maps_data" # output dataset and table in BQ
tmp_table_path = f"bq://{project_id}.{tmp_table}"
tmp_parquet_file = "airport_maps_data.parquet"
lakehouse_parquet_file = f"lakehouse/airport-maps/airport_maps_data.parquet"

# %% [markdown]
# #### Run the batch job prediction

# %%
def create_gemini_request(file_list):

    parts = [
        {
            "text": prompt
        }
    ]

    for file_data in file_list:
        parts.append({
            "file_data": {"file_uri": file_data, "mime_type": "application/pdf"}
        })

    request_dict = {
        "system_instruction": {
            "parts": [
                {
                    "text": system_instruction
                }
            ]
        },
        "contents": {
            "role": "user",
            "parts": parts
        },
        "generation_config": {
            "temperature": 1,
        },
    }

    return request_dict

# %%
storage_client = storage.Client()
genai_client = genai.Client(vertexai=True, project=project_id, location=region)

system_instruction = """
You are a helpful assistant who reads and understands airport terminal maps. Your goal is to ensure that an airport's businesses are properly reported.
You double-check your answers to make sure you are not mislabeling a business and always return your answers in json format.
"""

prompt = """Which businesses appear on the terminal map of this airport? Return their terminal, business name, category, and the nearest landmarks as they are shown on the map.
If the business is a dining establishment, return its menu items that it is known for.
Please make sure that your answer conforms to the output schema: {"terminal": "string", "business": "string", "category": "string", "location": "string", "dining": "boolean", "menu_items": "string"}
"""

jsonl_lines = []
file_listing = []
# get the file listings for the maps that we're going to process
bucket = storage_client.bucket(bucket_name)

cur_airport = None
prev_airport = None
num_airports = 0

for blob in bucket.list_blobs(prefix=input_folder_prefix):

    # make a separate dictionary request for each airport
    cur_airport = blob.name.split("-")[2].replace("maps/", "")

    if prev_airport == None or cur_airport == prev_airport:
        file_listing.append(f"gs://{bucket_name}/{blob.name}")
        prev_airport = cur_airport
    else:
        num_airports += 1
        request_dict = create_gemini_request(file_listing)

        jsonl_line = json.dumps({
            "key": prev_airport,  # row identifier
            "request": request_dict
        })

        #print(f"adding {prev_airport} to the input file")
        jsonl_lines.append(jsonl_line)
        file_listing.clear()

        # process cur_airport
        file_listing.append(f"gs://{bucket_name}/{blob.name}")
        prev_airport = cur_airport

if len(file_listing) > 0:
    request_dict = create_gemini_request(file_listing)

    jsonl_line = json.dumps({
        "key": cur_airport,  # use your row identifier here
        "request": request_dict
    })

    num_airports += 1
    jsonl_lines.append(jsonl_line)

print("Number of lines in jsonl file:", len(jsonl_lines))

# write all the lines to the jsonl file
if os.path.isdir(input_folder) != True:
    os.mkdir(input_folder)

with open(input_data_path, 'w') as f:
    for line in jsonl_lines:
        f.write(line + '\n')

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(input_data_path)
blob.upload_from_filename(input_data_path)

job = genai_client.batches.create(
    model=model_name,
    src=input_uri,
    config=CreateBatchJobConfig(
    dest=tmp_table_path
  )
)

print(f"Created job: {job.name} with {num_airports} airports")
print(f"Job {job.name} is currently in {job.state} state")
# Out:
# Number of lines in jsonl file: 88
# Created job: projects/988876466742/locations/us-central1/batchPredictionJobs/3326614434616442880 with 88 airports
# Job projects/988876466742/locations/us-central1/batchPredictionJobs/3326614434616442880 is currently in JobState.JOB_STATE_PENDING state

# %%
job = genai_client.batches.get(name=job.name)

while job.state not in (JobState.JOB_STATE_SUCCEEDED, JobState.JOB_STATE_FAILED,
                        JobState.JOB_STATE_CANCELLED, JobState.JOB_STATE_PAUSED):
    job = genai_client.batches.get(name=job.name)
    print(f"Job state: {job.state}")
    time.sleep(45)

print(f"Job state: {job.state}")
# Out:
# Job state: JobState.JOB_STATE_SUCCEEDED

# %% [markdown]
# #### Check the job results

# %%
# %%bigquery
# select key, response
# from air_travel_tmp.airport_maps_data
# where status not like '%error%'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     key                                           response
# 0   sfb  {"candidates":[{"avgLogprobs":-0.4782986346790...
# 1   bhm  {"candidates":[{"avgLogprobs":-0.2436348086257...
# 2   gtr  {"candidates":[{"avgLogprobs":-2.979052734375,...
# 3   cvg  {"candidates":[{"avgLogprobs":-0.3004618645363...
# 4   lch  {"candidates":[{"avgLogprobs":-0.2530112918749...
# ..  ...                                                ...
# 83  las  {"candidates":[{"avgLogprobs":-0.1664780419602...
# 84  oak  {"candidates":[{"avgLogprobs":-0.3259787659545...
# 85  fll  {"candidates":[{"avgLogprobs":-0.1240846142144...
# 86  lax  {"candidates":[{"avgLogprobs":-0.0798005497763...
# 87  sfo  {"candidates":[{"avgLogprobs":-0.0869813638806...
#
# [88 rows x 2 columns]

# %% [markdown]
# #### Create the parquet file

# %%
import pandas, pandas_gbq
import json
from google.cloud import storage

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

sql = f"""select key, response from {tmp_table} where status not like '%error%'
"""

df = pandas_gbq.read_gbq(
    sql,
    project_id=project_id,
    dialect="standard",
)

prediction_results = [] # key = product_id, value = dictionary containing predictions

# extract predictions from response
for index, row in df.iterrows():
    airport = row["key"]
    #print(f"airport: {airport}")
    response_dict = json.loads(row["response"])
    prediction_str = response_dict["candidates"][0]["content"]["parts"][0]["text"].replace("```", "").replace("json", "")
    prediction_list = json.loads(prediction_str)

    for prediction_dict in prediction_list:
        if type(prediction_dict) != dict:
            print(f"discarding: {prediction_dict}")
            continue
        prediction_dict.update({"airport": airport})
        prediction_results.append(prediction_dict)

print(f"number of results: {len(prediction_results)}")

# convert to parquet file
df = pandas.DataFrame(prediction_results)
df.to_parquet(tmp_parquet_file)
print("converted to parquet")

# upload to our lakehouse folder in GCS
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(lakehouse_parquet_file)
blob.upload_from_filename(tmp_parquet_file)
print(f"wrote parquet file to gs://{bucket_name}/{lakehouse_parquet_file}")
# Out:
# Downloading: 100%|██████████|
# number of results: 1465
# converted to parquet
# wrote parquet file to gs://air-travel-open-data/lakehouse/airport-maps/airport_maps_data.parquet

# %% [markdown]
# #### Create and load the Iceberg table

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE air_travel_raw.airport_maps
# (
#     airport STRING,
#     terminal STRING,
#     business STRING,
#     category STRING,
#     location STRING,
#     dining BOOLEAN,
#     menu_items STRING
# )
# WITH CONNECTION `988876466742.us-central1.cloud-storage-connection`
# OPTIONS (
#  file_format = 'PARQUET',
#  table_format = 'ICEBERG',
#  storage_uri = 'gs://air-travel-open-data/lakehouse/airport-maps'
# );
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# load data into air_travel_raw.airport_maps
#  from files (
#  format = 'parquet',
#  uris = ['gs://air-travel-open-data/lakehouse/airport-maps/airport_maps_data.parquet']);
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check the output

# %%
# %%bigquery
# select * from air_travel_raw.airport_maps
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      airport   terminal                        business      category  \
# 0        sfb  Level One                    Jetway Caffe        Dining
# 1        sfb  Level One                             TAB        Dining
# 2        sfb  Level Two                 Stanford Market      Shopping
# 3        sfb  Level Two                     Hudson News      Shopping
# 4        sfb  Level Two                   Port Paradise        Dining
# ...      ...        ...                             ...           ...
# 1460     sfo          3    COVID-19 Testing, XpresCheck       Service
# 1461     sfo          3  United Airline Baggage Service       Service
# 1462     sfo          3                      SFO Museum  Things to Do
# 1463     sfo          3                       Yoga Room  Things to Do
# 1464     sfo          3                     Kids' Spots  Things to Do
#
#                                location  dining  \
# 0     Near the Information Desk and ATM    True
# 1          Near the Global Entry office    True
# 2                          Near Gate 12   False
# 3                          Near Gate 11   False
# 4                          Near Gate 11    True
# ...                                 ...     ...
# 1460                  Level 1, Arrivals   False
# 1461                            Level 1   False
# 1462                  Pre-security area   False
# 1463                        Concourse E   False
# 1464              Near gates E7 and F18   False
#
#                                   menu_items
# 0         Coffee, pastries, and light snacks
# 1              Bar food, beer, and cocktails
# 2                                        N/A
# 3                                        N/A
# 4     Tropical-themed cocktails and bar food
# ...                                      ...
# 1460
# 1461
# 1462
# 1463
# 1464
#
# [1465 rows x 7 columns]

# %%
# %%bigquery
# select * from air_travel_raw.airport_maps
# where airport = 'aus'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    airport                  terminal                        business  \
# 0      aus            East Concourse                     Mini Market
# 1      aus            East Concourse                  The Scoreboard
# 2      aus            East Concourse                Hut's Hamburgers
# 3      aus            East Concourse                        Pretzels
# 4      aus            East Concourse                       Starbucks
# 5      aus            East Concourse                       Taste ATX
# 6      aus            East Concourse                      Second Bar
# 7      aus            East Concourse                        Parkside
# 8      aus            East Concourse               EJE Travel Retail
# 9      aus            East Concourse                            Jugo
# 10     aus            East Concourse            The Austin Chronicle
# 11     aus            East Concourse                       Vino Volo
# 12     aus            East Concourse             Tyler's Pop-up Shop
# 13     aus            East Concourse                   Caffe' Medici
# 14     aus            East Concourse                Noble Sandwiches
# 15     aus            East Concourse                     Zocalo Cafe
# 16     aus            East Concourse                         Toy Joy
# 17     aus            East Concourse              Sprinkles Cupcakes
# 18     aus            East Concourse                 Farmer's Fridge
# 19     aus            East Concourse                    Costa Coffee
# 20     aus            East Concourse                 Salvation Pizza
# 21     aus            East Concourse                        24 Diner
# 22     aus            East Concourse                    The Beerdrop
# 23     aus            East Concourse                  Barton Springs
# 24     aus            East Concourse                        Brighton
# 25     aus  Ticketing/Main Concourse                High Brew Coffee
# 26     aus  Ticketing/Main Concourse                 Farmer's Fridge
# 27     aus  Ticketing/Main Concourse                       Vino Volo
# 28     aus  Ticketing/Main Concourse                         Flyrite
# 29     aus  Ticketing/Main Concourse                  East Side Pies
# 30     aus  Ticketing/Main Concourse     Barton Springs Express Nook
# 31     aus  Ticketing/Main Concourse                 Jet Set Express
# 32     aus  Ticketing/Main Concourse      Earl Campbell's Taco Truck
# 33     aus  Ticketing/Main Concourse                     JO'S Coffee
# 34     aus  Ticketing/Main Concourse                  Austin Article
# 35     aus  Ticketing/Main Concourse                Amy's Ice Creams
# 36     aus  Ticketing/Main Concourse                     Book People
# 37     aus  Ticketing/Main Concourse                   The Saxon Pub
# 38     aus  Ticketing/Main Concourse               The Salt Lick BBQ
# 39     aus  Ticketing/Main Concourse            The Peached Tortilla
# 40     aus  Ticketing/Main Concourse                      Mad Greens
# 41     aus  Ticketing/Main Concourse                    Berry Austin
# 42     aus            West Concourse               Annies Cafe & Bar
# 43     aus            West Concourse          Ruta Maya Cafe & Books
# 44     aus            West Concourse               Austin Mercantile
# 45     aus            West Concourse                          Jetset
# 46     aus            West Concourse                        Haymaker
# 47     aus            West Concourse                  Caribou Coffee
# 48     aus            West Concourse               ThunderCloud Subs
# 49     aus            West Concourse                 Bartons Springs
# 50     aus             Baggage Claim   Carter Transportation Service
# 51     aus             Baggage Claim  TSA PreCheck Enrollment Center
# 52     aus             Baggage Claim          High Brew Coffee Kiosk
# 53     aus             Baggage Claim           24-Hour Flowers Kiosk
# 54     aus             Baggage Claim                   Smarte Cartes
# 55     aus             Baggage Claim                 Farmer's Fridge
# 56     aus             Baggage Claim               SIM Cards Vending
#
#             category                  location  dining  \
# 0           Shopping               Near Gate 1   False
# 1             Dining               Near Gate 1    True
# 2             Dining     Between Gates 1 and 3    True
# 3             Dining               Near Gate 3    True
# 4             Dining               Near Gate 3    True
# 5             Dining               Near Gate 5    True
# 6             Dining               Near Gate 5    True
# 7             Dining               Near Gate 5    True
# 8           Shopping               Near Gate 6   False
# 9             Dining               Near Gate 7    True
# 10          Shopping               Near Gate 7   False
# 11            Dining               Near Gate 7    True
# 12          Shopping               Near Gate 8   False
# 13            Dining               Near Gate 9    True
# 14            Dining               Near Gate 9    True
# 15            Dining              Near Gate 11    True
# 16          Shopping              Near Gate 11   False
# 17            Dining              Near Gate 12    True
# 18            Dining              Near Gate 12    True
# 19            Dining              Near Gate 13    True
# 20            Dining              Near Gate 13    True
# 21            Dining   Between Gates 13 and 15    True
# 22            Dining              Near Gate 14    True
# 23          Shopping              Near Gate 14   False
# 24          Shopping              Near Gate 15   False
# 25            Dining  Near security checkpoint    True
# 26            Dining  Near security checkpoint    True
# 27            Dining              Near Gate 22    True
# 28            Dining              Near Gate 22    True
# 29            Dining              Near Gate 22    True
# 30          Shopping              Near Gate 22   False
# 31          Shopping   Between Gates 21 and 22   False
# 32            Dining              Near Gate 21    True
# 33            Dining              Near Gate 21    True
# 34          Shopping              Near Gate 21   False
# 35            Dining              Near Gate 21    True
# 36          Shopping              Near Gate 21   False
# 37            Dining              Near Gate 20    True
# 38            Dining              Near Gate 20    True
# 39            Dining              Near Gate 17    True
# 40            Dining              Near Gate 17    True
# 41            Dining              Near Gate 16    True
# 42            Dining              Near Gate 31    True
# 43            Dining              Near Gate 30    True
# 44          Shopping              Near Gate 30   False
# 45          Shopping              Near Gate 28   False
# 46            Dining              Near Gate 24    True
# 47            Dining              Near Gate 24    True
# 48            Dining              Near Gate 23    True
# 49          Shopping              Near Gate 23   False
# 50  Airport Services       Baggage Claim level   False
# 51  Airport Services       Baggage Claim level   False
# 52            Dining       Baggage Claim level    True
# 53          Shopping       Baggage Claim level   False
# 54  Airport Services       Baggage Claim level   False
# 55            Dining       Baggage Claim level    True
# 56          Shopping       Baggage Claim level   False
#
#                              menu_items
# 0                                   N/A
# 1                      Bar food, drinks
# 2                            Hamburgers
# 3                              Pretzels
# 4          Coffee, pastries, sandwiches
# 5            Local Austin foods, snacks
# 6                   Cocktails, bar food
# 7           American cuisine, cocktails
# 8                                   N/A
# 9                      Juice, smoothies
# 10                                  N/A
# 11                   Wine, small plates
# 12                                  N/A
# 13           Coffee, espresso, pastries
# 14                           Sandwiches
# 15                 Mexican food, coffee
# 16                                  N/A
# 17                             Cupcakes
# 18        Salads, bowls, healthy snacks
# 19                     Coffee, pastries
# 20                                Pizza
# 21     American comfort food, breakfast
# 22                                 Beer
# 23                                  N/A
# 24                                  N/A
# 25                               Coffee
# 26        Salads, bowls, healthy snacks
# 27                   Wine, small plates
# 28                   Chicken sandwiches
# 29                                Pizza
# 30                                  N/A
# 31                                  N/A
# 32                                Tacos
# 33                     Coffee, pastries
# 34                                  N/A
# 35                            Ice cream
# 36                                  N/A
# 37           Beer, pub food, live music
# 38              Barbecue, brisket, ribs
# 39  Southern-Asian fusion, tacos, bowls
# 40                Salads, wraps, juices
# 41             Frozen yogurt, smoothies
# 42                Cafe food, bar drinks
# 43                        Coffee, books
# 44                                  N/A
# 45                                  N/A
# 46      Sandwiches, poutine, craft beer
# 47                     Coffee, pastries
# 48                 Submarine sandwiches
# 49                                  N/A
# 50                                  N/A
# 51                                  N/A
# 52                               Coffee
# 53                                  N/A
# 54                                  N/A
# 55        Salads, bowls, healthy snacks
# 56                                  N/A

# %% [markdown]
# #### Add the `_load_time` and `_data_source` fields to the table

# %%
# %%bigquery
#
# alter table air_travel_raw.airport_maps
#     add column _data_source STRING, add column _load_time TIMESTAMP;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# update air_travel_raw.airport_maps
#     set _data_source = 'airport.guide', _load_time = current_timestamp()
#     where 1 = 1
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### Check final output

# %%
# %%bigquery
#
# select * from air_travel_raw.airport_maps
# where airport = 'lax'
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     airport       terminal          business        category  \
# 0       lax              1      Deli and Co.          Dining
# 1       lax              5          Loteria!          Dining
# 2       lax  International  Planet Hollywood        Shopping
# 3       lax              4     DFS Duty Free        Shopping
# 4       lax              6       Market 8600          Dining
# ..      ...            ...               ...             ...
# 168     lax              1       Chick-fil-A          Dining
# 169     lax              4  AA Admirals Club  Airline Lounge
# 170     lax              7     DFS Duty Free        Shopping
# 171     lax  International   iStore Boutique        Shopping
# 172     lax  International         Vino Volo          Dining
#
#                       location  dining  \
# 0                Near Gate 11B    True
# 1                Near Gate 53A    True
# 2                Near Gate 131   False
# 3                 Near Gate 41   False
# 4                Near Gate 64A    True
# ..                         ...     ...
# 168  Between Gates 11A and 11B    True
# 169               Near Gate 40   False
# 170              Near Gate 71A   False
# 171                  Main Hall   False
# 172              Near Gate 148    True
#
#                                     menu_items   _data_source  \
# 0          Deli sandwiches, salads, and snacks  airport.guide
# 1                          Mexican street food  airport.guide
# 2                                          N/A  airport.guide
# 3                                          N/A  airport.guide
# 4                     Grab-and-go market items  airport.guide
# ..                                         ...            ...
# 168  Chicken sandwiches, nuggets, waffle fries  airport.guide
# 169                                        N/A  airport.guide
# 170                                        N/A  airport.guide
# 171                                        N/A  airport.guide
# 172                         Wine, small plates  airport.guide
#
#                           _load_time
# 0   2025-09-12 17:51:04.394764+00:00
# 1   2025-09-12 17:51:04.394764+00:00
# 2   2025-09-12 17:51:04.394764+00:00
# 3   2025-09-12 17:51:04.394764+00:00
# 4   2025-09-12 17:51:04.394764+00:00
# ..                               ...
# 168 2025-09-12 17:51:04.394764+00:00
# 169 2025-09-12 17:51:04.394764+00:00
# 170 2025-09-12 17:51:04.394764+00:00
# 171 2025-09-12 17:51:04.394764+00:00
# 172 2025-09-12 17:51:04.394764+00:00
#
# [173 rows x 9 columns]

# %% [markdown]
# ### TSA Traffic

# %%
input_folder_prefix = "initial-loads/tsa-traffic" # where our input pdfs are located
input_folder = "jsonl/tsa-traffic"
input_data_path = f"{input_folder}/input-data.jsonl" # used for both the local file and GCS file, contains the prediction requests
input_uri = f"gs://{bucket_name}/{input_data_path}" # complete path to file containing the prediction requests
tmp_table = "air_travel_tmp.tsa_traffic_data" # output dataset and table in BQ
tmp_table_path = f"bq://{project_id}.{tmp_table}"
tmp_parquet_file = "tsa_traffic_data.parquet"
lakehouse_parquet_file = f"lakehouse/tsa-traffic/tsa_traffic_data.parquet"

# %% [markdown]
# #### Run the batch job prediction

# %%
def create_gemini_request(file_list):

    parts = [
        {
            "text": prompt
        }
    ]

    for file_data in file_list:
        parts.append({
            "file_data": {"file_uri": file_data, "mime_type": "application/pdf"}
        })

    request_dict = {
        "system_instruction": {
            "parts": [
                {
                    "text": system_instruction
                }
            ]
        },
        "contents": {
            "role": "user",
            "parts": parts
        },
        "generation_config": {
            "temperature": 1,
        },
    }

    return request_dict

# %%
storage_client = storage.Client()
genai_client = genai.Client(vertexai=True, project=project_id, location=region)

system_instruction = """
You are a helpful assistant who reads and understands tsa traffic reports. Your goal is to ensure that an airport's traffic patterns is properly reported.
You double-check your answers to make sure you are not mislabeling a checkpoint or reporting wrong numbers and always return your answers in json format.
"""

prompt = """Convert the file to json format. Return the date, hour of day, airport code, airport name, city, state, checkpoint name, and total traffic reported for each time period and location.
Please make sure that your answer conforms to the output schema:
  {"day": "string", "hour": "string, "terminal": "airport_code", "airport_name": "string", "city": "string", "state": "string", "checkpoint": "string", "total_traffic": "integer"}
"""

jsonl_lines = []

# get the file listings for the maps that we're going to process
bucket = storage_client.bucket(bucket_name)

num_reports = 0

for blob in bucket.list_blobs(prefix=input_folder_prefix):

    num_reports += 1

    # make a separate request per pdf
    file_name = blob.name.replace("air-travel-open-data/initial-loads/tsa-traffic", "").replace(".pdf", "")
    file_path = f"gs://{bucket_name}/{blob.name}"

    request_dict = create_gemini_request(file_path)

    jsonl_line = json.dumps({
        "key": file_name,  # row identifier
        "request": request_dict
    })

    jsonl_lines.append(jsonl_line)

print("number of lines in jsonl file:", len(jsonl_lines))

# write all the lines to the jsonl file
if os.path.isdir(input_folder) != True:
    os.mkdir(input_folder)

with open(input_data_path, 'w') as f:
    for line in jsonl_lines:
        f.write(line + '\n')

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(input_data_path)
blob.upload_from_filename(input_data_path)

job = genai_client.batches.create(
    model=model_name,
    src=input_uri,
    config=CreateBatchJobConfig(
    dest=tmp_table_path
  )
)

print(f"Created job: {job.name} with {num_reports} tsa reports")
print(f"Job {job.name} is currently in {job.state} state")
# Out:
# number of lines in jsonl file: 110
# Created job: projects/988876466742/locations/us-central1/batchPredictionJobs/3211702275374317568 with 110 tsa reports
# Job projects/988876466742/locations/us-central1/batchPredictionJobs/3211702275374317568 is currently in JobState.JOB_STATE_PENDING state

# %%
job = genai_client.batches.get(name=job.name)

while job.state not in (JobState.JOB_STATE_SUCCEEDED, JobState.JOB_STATE_FAILED,
                        JobState.JOB_STATE_CANCELLED, JobState.JOB_STATE_PAUSED):
    job = genai_client.batches.get(name=job.name)
    print(f"Job state: {job.state}")
    time.sleep(45)

print(f"Job state: {job.state}")
# Out:
# Job state: JobState.JOB_STATE_PENDING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_RUNNING
# Job state: JobState.JOB_STATE_SUCCEEDED
# Job state: JobState.JOB_STATE_SUCCEEDED

# %% [markdown]
# #### Check the job results

# %%
# %%bigquery
# select key, response
# from air_travel_tmp.tsa_traffic_data
# where status not like '%error%'

# %% [markdown]
# #### Create the parquet file

# %%
import pandas, pandas_gbq
import json
from google.cloud import storage

storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

sql = f"""select key, response from {tmp_table} where status not like '%error%'
"""

df = pandas_gbq.read_gbq(
    sql,
    project_id=project_id,
    dialect="standard",
)

prediction_results = [] # key = product_id, value = dictionary containing predictions

# extract predictions from response
for index, row in df.iterrows():
    airport = row["key"]
    #print(f"airport: {airport}")
    response_dict = json.loads(row["response"])
    prediction_str = response_dict["candidates"][0]["content"]["parts"][0]["text"].replace("```", "").replace("json", "")
    prediction_list = json.loads(prediction_str)

    for prediction_dict in prediction_list:
        if type(prediction_dict) != dict:
            print(f"discarding: {prediction_dict}")
            continue
        prediction_results.append(prediction_dict)

print(f"number of results: {len(prediction_results)}")

# convert to parquet file
df = pandas.DataFrame(prediction_results)
df.to_parquet(tmp_parquet_file)
print("converted to parquet")

# upload to our lakehouse folder in GCS
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)
blob = bucket.blob(lakehouse_parquet_file)
blob.upload_from_filename(tmp_parquet_file)
print(f"wrote parquet file to gs://{bucket_name}/{lakehouse_parquet_file}")

# %% [markdown]
# #### Create and load the Iceberg table

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE air_travel_raw.tsa_traffic
# (
#     day STRING,
#     hour STRING,
#     airport_code STRING,
#     airport_name STRING,
#     city STRING,
#     state STRING,
#     checkpoint STRING,
#     total_traffic INTEGER
# )
# WITH CONNECTION `988876466742.us-central1.cloud-storage-connection`
# OPTIONS (
#  file_format = 'PARQUET',
#  table_format = 'ICEBERG',
#  storage_uri = 'gs://air-travel-open-data/lakehouse/tsa-traffic'
# );

# %%
# %%bigquery
#
# load data into air_travel_raw.tsa_traffic
#  from files (
#  format = 'parquet',
#  uris = ['gs://air-travel-open-data/lakehouse/airport-maps/tsa_traffic_data.parquet']);

# %% [markdown]
# #### Check the output

# %%
# %%bigquery
# select * from air_travel_raw.tsa_traffic

# %% [markdown]
# #### Add the `_load_time` and `_data_source` fields to the table

# %%
# %%bigquery
#
# alter table air_travel_raw.airport_maps
#     add column _data_source STRING, add column _load_time TIMESTAMP;

# %%
# %%bigquery
#
# update air_travel_raw.airport_maps
#     set _data_source = 'tsa', _load_time = current_timestamp()
#     where 1 = 1

# %% [markdown]
# #### Check final output

# %%
# %%bigquery
#
# select * from air_travel_raw.airport_maps
# where airport = 'lax'
